# %%
import time
import pandas as pd
from pathlib import Path
from openaq import OpenAQ
import requests
import json
import copy

# %%
with open("credentials.json", 'r') as f:
    credentials = json.load(f)

# %%
# client = OpenAQ(api_key=credentials['OPENAQ-API-KEY'])
# location_response = client.locations.list(coordinates=[41.88831156293874, -87.65155282542493], radius=24999, limit=1000).json()
headers = {"X-API-Key" : credentials['OPENAQ-API-KEY']}
coords = (41.88831156293874, -87.65155282542493)
radius = 24999
limit = 100
url = f"https://api.openaq.org/v3/locations?coordinates={str(coords[0])}%2C%20{str(coords[1])}&radius={radius}&limit={limit}&page=1&order_by=id&sort_order=asc"
loc_response = requests.get(url, headers=headers).json()

with open("Chicago_response.json", 'w') as f:
    json.dump(loc_response, f, indent=4)

# %%
loc_response
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 22},
#  'results': [{'id': 424,
#    'name': 'CHI_COM',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 737,
#      'name': 'o3 ppm',
#      'parameter': {'id': 10,
#       'name': 'o3',
#       'units': 'ppm',
#       'displayName': 'O₃'}},
#     {'id': 2933,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.7547, 'longitude': -87.7136},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.7136, 41.7547, -87.7136, 41.7547],
#    'distance': 15710.28328703,
#    'datetimeFirst': {'utc': '2016-03-06T20:00:00Z',
#     'local': '2016-03-06T14:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 1657,
#    'name': 'CHI_SP',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 2934,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.9136, 'longitude': -87.7239},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.7239, 41.9136, -87.7239, 41.9136],
#    'distance': 6632.4210276,
#    'datetimeFirst': {'utc': '2016-03-11T16:00:00Z',
#     'local': '2016-03-11T10:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 1658,
#    'name': 'CHI_SWFP',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 5077774,
#      'name': 'o3 ppm',
#      'parameter': {'id': 10,
#       'name': 'o3',
#       'units': 'ppm',
#       'displayName': 'O₃'}}],
#    'coordinates': {'latitude': 41.755798, 'longitude': -87.545303},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.545303, 41.755798, -87.545303, 41.755798],
#    'distance': 17159.08131248,
#    'datetimeFirst': {'utc': '2022-10-04T18:00:00Z',
#     'local': '2022-10-04T13:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 1660,
#    'name': 'CICERO',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 5077803,
#      'name': 'o3 ppm',
#      'parameter': {'id': 10,
#       'name': 'o3',
#       'units': 'ppm',
#       'displayName': 'O₃'}}],
#    'coordinates': {'latitude': 41.855301, 'longitude': -87.752502},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.752502, 41.855301, -87.752502, 41.855301],
#    'distance': 9150.94912812,
#    'datetimeFirst': {'utc': '2022-10-04T18:00:00Z',
#     'local': '2022-10-04T13:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 1856,
#    'name': 'Cicero Liberty',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 3277,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.864329, 'longitude': -87.748826},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.748826, 41.864329, -87.748826, 41.864329],
#    'distance': 8506.53412597,
#    'datetimeFirst': {'utc': '2016-03-06T20:00:00Z',
#     'local': '2016-03-06T14:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 2085,
#    'name': 'SCHILPRK',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 3716,
#      'name': 'o3 ppm',
#      'parameter': {'id': 10,
#       'name': 'o3',
#       'units': 'ppm',
#       'displayName': 'O₃'}},
#     {'id': 2087664,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.965, 'longitude': -87.8761},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.8761, 41.965, -87.8761, 41.965],
#    'distance': 20485.11468417,
#    'datetimeFirst': {'utc': '2016-03-06T20:00:00Z',
#     'local': '2016-03-06T14:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 2235,
#    'name': 'EVANSTON',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4034,
#      'name': 'o3 ppm',
#      'parameter': {'id': 10,
#       'name': 'o3',
#       'units': 'ppm',
#       'displayName': 'O₃'}}],
#    'coordinates': {'latitude': 42.0622, 'longitude': -87.6736},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.6736, 42.0622, -87.6736, 42.0622],
#    'distance': 19402.21721674,
#    'datetimeFirst': {'utc': '2016-04-04T13:00:00Z',
#     'local': '2016-04-04T08:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 8468,
#    'name': 'CHI_TAFT',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 5077782,
#      'name': 'o3 ppm',
#      'parameter': {'id': 10,
#       'name': 'o3',
#       'units': 'ppm',
#       'displayName': 'O₃'}}],
#    'coordinates': {'latitude': 41.984402, 'longitude': -87.791901},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.791901, 41.984402, -87.791901, 41.984402],
#    'distance': 15796.20632503,
#    'datetimeFirst': {'utc': '2022-10-04T18:00:00Z',
#     'local': '2022-10-04T13:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 1370216,
#    'name': 'West Albany Park, Chicago',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'},
#     {'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 7979159,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7971260,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7971006,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7979145,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7979186,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 6664821,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7973216,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 7979183,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 6664822,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 7973201,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.962434, 'longitude': -87.737472},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.737472, 41.962434, -87.737472, 41.962434],
#    'distance': 10892.91019799,
#    'datetimeFirst': {'utc': '2023-08-02T01:00:00Z',
#     'local': '2023-08-01T20:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T23:00:00Z',
#     'local': '2025-09-11T18:00:00-05:00'}},
#   {'id': 1443036,
#    'name': 'Winona',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 1, 'name': 'N/A'},
#     {'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 7970927,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7979889,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7979876,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7971067,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 6764273,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7973023,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 6764272,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 7973069,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.9856384, 'longitude': -87.6675072},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.6675072, 41.9856384, -87.6675072, 41.9856384],
#    'distance': 10892.77225631,
#    'datetimeFirst': {'utc': '2023-08-16T17:00:00Z',
#     'local': '2023-08-16T12:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-07-16T15:00:00Z',
#     'local': '2025-07-16T10:00:00-05:00'}},
#   {'id': 2047319,
#    'name': 'McCook',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 7635192,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.80117, 'longitude': -87.83194},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.83194, 41.80117, -87.83194, 41.80117],
#    'distance': 17839.03943018,
#    'datetimeFirst': {'utc': '2024-01-02T17:00:00Z',
#     'local': '2024-01-02T11:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 3027117,
#    'name': 'Portage Park - Chicago',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 11116, 'name': 'Don Madden'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 10342178,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 10342181,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 10342175,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 10342177,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 10342174,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 10342172,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.9480557275771,
#     'longitude': -87.74637848791646},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'Don Madden', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.74637848791646,
#     41.9480557275771,
#     -87.74637848791646,
#     41.9480557275771],
#    'distance': 10295.71565975,
#    'datetimeFirst': {'utc': '2024-08-21T17:00:00Z',
#     'local': '2024-08-21T12:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T23:00:00Z',
#     'local': '2025-09-11T18:00:00-05:00'}},
#   {'id': 3069356,
#    'name': 'Fairfield Avenue',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 11165, 'name': 'kbx81'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 10660009,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 10660013,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 10659980,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 10660024,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 10660030,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 10659976,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.92650874937315,
#     'longitude': -87.69594397165164},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'kbx81', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.69594397165164,
#     41.92650874937315,
#     -87.69594397165164,
#     41.92650874937315],
#    'distance': 5622.16457337,
#    'datetimeFirst': {'utc': '2024-09-18T23:00:00Z',
#     'local': '2024-09-18T18:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-04-05T22:00:00Z',
#     'local': '2025-04-05T17:00:00-05:00'}},
#   {'id': 3301365,
#    'name': 'CHI_MAYFAIR',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 11543361,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.96548, 'longitude': -87.74992},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.74992, 41.96548, -87.74992, 41.96548],
#    'distance': 11837.68919186,
#    'datetimeFirst': {'utc': '2024-12-04T16:00:00Z',
#     'local': '2024-12-04T10:00:00-06:00'},
#    'datetimeLast': {'utc': '2024-12-05T15:00:00Z',
#     'local': '2024-12-05T09:00:00-06:00'}},
#   {'id': 3301366,
#    'name': 'CHI_MAYFAIR',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 11543362,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.96548, 'longitude': -87.74992},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.74992, 41.96548, -87.74992, 41.96548],
#    'distance': 11837.68919186,
#    'datetimeFirst': {'utc': '2024-12-04T16:00:00Z',
#     'local': '2024-12-04T10:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 3368525,
#    'name': 'CHI_WASH',
#    'locality': 'Chicago-Naperville-Joliet',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 12023512,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.6878, 'longitude': -87.5389},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.5389, 41.6878, -87.5389, 41.6878],
#    'distance': 24156.40673885,
#    'datetimeFirst': {'utc': '2025-01-14T18:00:00Z',
#     'local': '2025-01-14T12:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 3560429,
#    'name': 'Nettelhorst',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 11216, 'name': 'Nettelhorst Idling Crew'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 12360075,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 12360076,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 12360077,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 12360078,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 12360079,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.9418081, 'longitude': -87.6445189},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'Nettelhorst Idling Crew', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.6445189, 41.9418081, -87.6445189, 41.9418081],
#    'distance': 5971.38442952,
#    'datetimeFirst': {'utc': '2025-03-03T02:00:00Z',
#     'local': '2025-03-02T20:00:00-06:00'},
#    'datetimeLast': {'utc': '2025-09-11T23:00:00Z',
#     'local': '2025-09-11T18:00:00-05:00'}},
#   {'id': 4139028,
#    'name': 'Summit',
#    'locality': 'COOK',
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 12856503,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 41.78276, 'longitude': -87.80537},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [-87.80537, 41.78276, -87.80537, 41.78276],
#    'distance': 17342.64976677,
#    'datetimeFirst': {'utc': '2025-04-21T19:00:00Z',
#     'local': '2025-04-21T14:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#     'local': '2025-09-11T17:00:00-05:00'}},
#   {'id': 4609260,
#    'name': 'Avalon Park',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 13230356,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 13230357,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 13230358,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 13230359,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 13230360,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.7441079, 'longitude': -87.5939035},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.5939035, 41.7441079, -87.5939035, 41.7441079],
#    'distance': 16715.09445242,
#    'datetimeFirst': {'utc': '2025-06-03T12:00:00Z',
#     'local': '2025-06-03T07:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T23:00:00Z',
#     'local': '2025-09-11T18:00:00-05:00'}},
#   {'id': 4645153,
#    'name': 'South Loop',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 13760568,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 13760569,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 13760570,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 13760571,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 13760572,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.865, 'longitude': -87.622},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.622, 41.865, -87.622, 41.865],
#    'distance': 3562.88839504,
#    'datetimeFirst': {'utc': '2025-08-02T11:00:00Z',
#     'local': '2025-08-02T06:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T23:00:00Z',
#     'local': '2025-09-11T18:00:00-05:00'}},
#   {'id': 4892079,
#    'name': 'Jeff Park',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 2191, 'name': 'David'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 13457439,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 13457440,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 13457441,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 13457442,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 13457443,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.9678, 'longitude': -87.774},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'David', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.774, 41.9678, -87.774, 41.9678],
#    'distance': 13461.47451509,
#    'datetimeFirst': {'utc': '2025-06-28T21:00:00Z',
#     'local': '2025-06-28T16:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T23:00:00Z',
#     'local': '2025-09-11T18:00:00-05:00'}},
#   {'id': 4903652,
#    'name': 'Wells & Ontario Bus Station',
#    'locality': None,
#    'timezone': 'America/Chicago',
#    'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 13477544,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 13477545,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 13477546,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 13477547,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 13477548,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 41.893333, 'longitude': -87.634176},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [-87.634176, 41.893333, -87.634176, 41.893333],
#    'distance': 1542.61190208,
#    'datetimeFirst': {'utc': '2025-07-01T00:00:00Z',
#     'local': '2025-06-30T19:00:00-05:00'},
#    'datetimeLast': {'utc': '2025-09-11T23:00:00Z',
#     'local': '2025-09-11T18:00:00-05:00'}}]}

# %%
def get_data(sensor_id:int, datetime_from: str, datetime_to: str, location_name:str, latitude:str, longitude:str, country_name:str, total_api_calls:int):
    global TOTAL_API_CALLS
    headers = {"X-API-Key" : credentials['OPENAQ-API-KEY']}
    data_dict = {}
    page=1
    limit=1000

    print(f"\nsensor_id: {sensor_id} | Fetching data from {datetime_from} to {datetime_to}")

    while True:
        url = f"https://api.openaq.org/v3/sensors/{sensor_id}/hours?datetime_to={datetime_to}&datetime_from={datetime_from}&limit=1000&page={page}"
        # readings = client.measurements.list(sensors_id=sensor_id, limit=limit, page=page, datetime_from=datetime_from, datetime_to=datetime_to)

        readings = requests.get(url, headers=headers)
        readings.raise_for_status()
        
        total_api_calls += 1

        readings = readings.json()

        if readings['meta']['found'] == 0:
            print(f"No readings found from {datetime_from} to {datetime_to}")
            return total_api_calls

        if page==1:
            pollutant_name = readings['results'][0]['parameter']['name']
            unit = readings['results'][0]['parameter']['units']

            page_timestamps = [f['period']['datetimeTo']['utc'] for f in readings['results']]
            data_dict['Timestamp'] = page_timestamps
            for stat in ['min', 'q02', 'q25', 'median', 'q75', 'q98', 'max', 'avg', 'sd']:
                stat_data = [f['summary'][stat] for f in readings['results'] if stat in f.get('summary', {})]
                stat_col_name = f"{stat}"
                data_dict[stat_col_name] = stat_data
        else:
            data_dict['Timestamp'] = data_dict['Timestamp'] + [f['period']['datetimeTo']['utc'] for f in readings['results']]
            for stat in ['min', 'q02', 'q25', 'median', 'q75', 'q98', 'max', 'avg', 'sd']:
                stat_data = [f['summary'][stat] for f in readings['results'] if stat in f.get('summary', {})]
                stat_col_name = f"{stat}"
                data_dict[stat_col_name] = data_dict[stat_col_name] + stat_data
        


        print(f"sensor_id: {sensor_id} | Fetched {len(stat_data)} readings from page {page} | Total readings - {len(data_dict['Timestamp'])}")
        if len(stat_data)<limit:
            print("Reached the end of data.")
            break

        page += 1
    
    print(f"Finished Fetching all data. Total readings are {len(data_dict['Timestamp'])} for sensor {sensor_id}")
    
    if len(page_timestamps)>0:
        data_df = pd.DataFrame(data_dict)
        data_df['pollutant'] = pollutant_name
        data_df['location_name'] = location_name
        data_df['latitude'] = latitude
        data_df['longitude'] = longitude
        data_df['unit'] = unit
        data_df['sensor_id'] = sensor_id
        data_df['city_name'] = "Chicago"
        data_df['state'] = "Illinois"
        data_df['country'] = country_name
        data_file_path = Path("AQ_data") / "Chicago" / location_name / str(sensor_id) / datetime_from[:4]/ datetime_to.split("-")[1]
        data_file_path.mkdir(exist_ok=True, parents=True)
        file_name = data_file_path / (pollutant_name+"_"+str(sensor_id)+'.csv')
        # print(type(file_name), file_name)
        data_df.to_csv(file_name, index=False)
        print(f"saved the data to {file_name}")
    
    return total_api_calls

# %%
TOTAL_API_CALLS = 0
def get_sensor_data(location_id:int, location_name:str, latitude:float, longitude:float, country_name:str):
    url = f"https://api.openaq.org/v3/locations/{location_id}/sensors"
    headers = {"X-API-Key" : credentials['OPENAQ-API-KEY']}
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    response = response.json()
    global TOTAL_API_CALLS

    sensor_ids = [sensor['id'] for sensor in response['results'] if sensor.get('coverage')]
    year_first = [int(sensor['datetimeFirst']['utc'][:4]) for sensor in response['results'] if sensor.get('coverage')]
    year_last = [int(sensor['datetimeLast']['utc'][:4]) for sensor in response['results'] if sensor.get('coverage')]
    years = [list(range(year1, year2+1)) for year1, year2 in zip(year_first, year_last)]

    start= time.time()
    for k in range(len(sensor_ids)):
        
            sensor_id = sensor_ids[k]
            for year in years[k]:
                try:
                    TOTAL_API_CALLS_2 = copy.copy(TOTAL_API_CALLS)
                    TOTAL_API_CALLS = get_data(sensor_id=sensor_id, 
                                               datetime_from=f"{str(year)}-01-01", 
                                               datetime_to=f"{str(year)}-06-30",
                                               location_name=location_name,
                                               latitude=latitude,
                                               longitude=longitude,
                                               country_name=country_name,
                                               total_api_calls=TOTAL_API_CALLS)
                    TOTAL_API_CALLS = get_data(sensor_id=sensor_id,
                                               datetime_from=f"{str(year)}-07-01",
                                               datetime_to=f"{str(year)}-12-31",
                                               location_name=location_name,
                                               latitude=latitude,
                                               longitude=longitude,
                                               country_name=country_name,
                                               total_api_calls=TOTAL_API_CALLS)
                    stop = time.time()
                    time.sleep(5)
                    print(f"\ntime elapsed: {(stop-start):.4f} | {TOTAL_API_CALLS = }\n")
                    if (stop-start) > 540:
                        time.sleep(40)

                except:
                    print(f"Ran into key error. Retrying after 2 minutes\n\n")
                    time.sleep(120)
                    TOTAL_API_CALLS = TOTAL_API_CALLS_2
                    TOTAL_API_CALLS = get_data(sensor_id=sensor_id,
                                               datetime_from=f"{str(year)}-01-01",
                                               datetime_to=f"{str(year)}-06-30",
                                               location_name=location_name,
                                               latitude=latitude,
                                               longitude=longitude,
                                               country_name=country_name,
                                               total_api_calls=TOTAL_API_CALLS)
                    
                    TOTAL_API_CALLS = get_data(sensor_id=sensor_id,
                                               datetime_from=f"{str(year)}-07-01",
                                               datetime_to=f"{str(year)}-12-31",
                                               location_name=location_name,
                                               latitude=latitude,
                                               longitude=longitude,
                                               country_name=country_name,
                                               total_api_calls=TOTAL_API_CALLS)
                    stop = time.time()
                    time.sleep(30)
                    print(f"time elapsed: {(stop-start):.4f} | {TOTAL_API_CALLS = }")

# %%
for loc in loc_response['results'][8:]:
    country_name = loc['country']['name']
    latitude = loc['coordinates']['latitude'] if loc['coordinates'].get('latitude') else None
    longitude = loc['coordinates']['longitude'] if loc['coordinates'].get('longitude') else None
    get_sensor_data(location_id=loc['id'], location_name=loc['name'], latitude=latitude, longitude=longitude, country_name=country_name)
# Out:
# sensor_id: 6664822 | Fetching data from 2023-01-01 to 2023-06-30
# No readings found from 2023-01-01 to 2023-06-30
#
# sensor_id: 6664822 | Fetching data from 2023-07-01 to 2023-12-31
# sensor_id: 6664822 | Fetched 216 readings from page 1 | Total readings - 216
# Reached the end of data.
# Finished Fetching all data. Total readings are 216 for sensor 6664822
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664822\2023\12\temperature_6664822.csv
#
# time elapsed: 0.6238 | TOTAL_API_CALLS = 2
#
#
# sensor_id: 6664822 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 6664822 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664822 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6664822 | Fetched 420 readings from page 3 | Total readings - 2420
# Reached the end of data.
# Finished Fetching all data. Total readings are 2420 for sensor 6664822
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664822\2024\06\temperature_6664822.csv
#
# sensor_id: 6664822 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 6664822 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664822 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6664822 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6664822 | Fetched 246 readings from page 4 | Total readings - 3246
# Reached the end of data.
# Finished Fetching all data. Total readings are 3246 for sensor 6664822
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664822\2024\12\temperature_6664822.csv
#
# time elapsed: 15.0140 | TOTAL_API_CALLS = 9
#
#
# sensor_id: 6664822 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 6664822 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664822 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6664822 | Fetched 507 readings from page 3 | Total readings - 2507
# Reached the end of data.
# Finished Fetching all data. Total readings are 2507 for sensor 6664822
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664822\2025\06\temperature_6664822.csv
#
# sensor_id: 6664822 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 6664822 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664822 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 6664822
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664822\2025\12\temperature_6664822.csv
#
# time elapsed: 26.9053 | TOTAL_API_CALLS = 14
#
#
# sensor_id: 7971006 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7971006 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971006 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7971006 | Fetched 372 readings from page 3 | Total readings - 2372
# Reached the end of data.
# Finished Fetching all data. Total readings are 2372 for sensor 7971006
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7971006\2024\06\pm10_7971006.csv
#
# sensor_id: 7971006 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7971006 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971006 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7971006 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7971006 | Fetched 246 readings from page 4 | Total readings - 3246
# Reached the end of data.
# Finished Fetching all data. Total readings are 3246 for sensor 7971006
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7971006\2024\12\pm10_7971006.csv
#
# time elapsed: 41.9452 | TOTAL_API_CALLS = 21
#
#
# sensor_id: 7971260 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7971260 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971260 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7971260 | Fetched 372 readings from page 3 | Total readings - 2372
# Reached the end of data.
# Finished Fetching all data. Total readings are 2372 for sensor 7971260
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7971260\2024\06\pm1_7971260.csv
#
# sensor_id: 7971260 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7971260 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971260 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7971260 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7971260 | Fetched 246 readings from page 4 | Total readings - 3246
# Reached the end of data.
# Finished Fetching all data. Total readings are 3246 for sensor 7971260
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7971260\2024\12\pm1_7971260.csv
#
# time elapsed: 56.1624 | TOTAL_API_CALLS = 28
#
#
# sensor_id: 7971260 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7971260 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971260 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7971260 | Fetched 507 readings from page 3 | Total readings - 2507
# Reached the end of data.
# Finished Fetching all data. Total readings are 2507 for sensor 7971260
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7971260\2025\06\pm1_7971260.csv
#
# sensor_id: 7971260 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 7971260 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971260 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 7971260
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7971260\2025\12\pm1_7971260.csv
#
# time elapsed: 67.3151 | TOTAL_API_CALLS = 33
#
#
# sensor_id: 6664821 | Fetching data from 2023-01-01 to 2023-06-30
# No readings found from 2023-01-01 to 2023-06-30
#
# sensor_id: 6664821 | Fetching data from 2023-07-01 to 2023-12-31
# sensor_id: 6664821 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664821 | Fetched 437 readings from page 2 | Total readings - 1437
# Reached the end of data.
# Finished Fetching all data. Total readings are 1437 for sensor 6664821
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664821\2023\12\pm25_6664821.csv
#
# time elapsed: 74.4205 | TOTAL_API_CALLS = 36
#
#
# sensor_id: 6664821 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 6664821 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664821 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6664821 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6664821 | Fetched 576 readings from page 4 | Total readings - 3576
# Reached the end of data.
# Finished Fetching all data. Total readings are 3576 for sensor 6664821
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664821\2024\06\pm25_6664821.csv
#
# sensor_id: 6664821 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 6664821 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664821 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6664821 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6664821 | Fetched 246 readings from page 4 | Total readings - 3246
# Reached the end of data.
# Finished Fetching all data. Total readings are 3246 for sensor 6664821
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664821\2024\12\pm25_6664821.csv
#
# time elapsed: 90.7578 | TOTAL_API_CALLS = 44
#
#
# sensor_id: 6664821 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 6664821 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664821 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6664821 | Fetched 507 readings from page 3 | Total readings - 2507
# Reached the end of data.
# Finished Fetching all data. Total readings are 2507 for sensor 6664821
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664821\2025\06\pm25_6664821.csv
#
# sensor_id: 6664821 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 6664821 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6664821 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 6664821
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\6664821\2025\12\pm25_6664821.csv
#
# time elapsed: 101.9537 | TOTAL_API_CALLS = 49
#
#
# sensor_id: 7979159 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7979159 | Fetched 44 readings from page 1 | Total readings - 44
# Reached the end of data.
# Finished Fetching all data. Total readings are 44 for sensor 7979159
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7979159\2024\06\pm1_7979159.csv
#
# sensor_id: 7979159 | Fetching data from 2024-07-01 to 2024-12-31
# No readings found from 2024-07-01 to 2024-12-31
#
# time elapsed: 107.5044 | TOTAL_API_CALLS = 51
#
#
# sensor_id: 7973201 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7973201 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973201 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973201 | Fetched 405 readings from page 3 | Total readings - 2405
# Reached the end of data.
# Finished Fetching all data. Total readings are 2405 for sensor 7973201
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973201\2024\06\um003_7973201.csv
#
# sensor_id: 7973201 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7973201 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973201 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973201 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7973201 | Fetched 246 readings from page 4 | Total readings - 3246
# Reached the end of data.
# Finished Fetching all data. Total readings are 3246 for sensor 7973201
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973201\2024\12\um003_7973201.csv
#
# time elapsed: 122.0736 | TOTAL_API_CALLS = 58
#
#
# sensor_id: 7973201 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7973201 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973201 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973201 | Fetched 507 readings from page 3 | Total readings - 2507
# Reached the end of data.
# Finished Fetching all data. Total readings are 2507 for sensor 7973201
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973201\2025\06\um003_7973201.csv
#
# sensor_id: 7973201 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 7973201 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973201 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 7973201
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973201\2025\12\um003_7973201.csv
#
# time elapsed: 134.2124 | TOTAL_API_CALLS = 63
#
#
# sensor_id: 7979145 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7979145 | Fetched 44 readings from page 1 | Total readings - 44
# Reached the end of data.
# Finished Fetching all data. Total readings are 44 for sensor 7979145
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7979145\2024\06\pm10_7979145.csv
#
# sensor_id: 7979145 | Fetching data from 2024-07-01 to 2024-12-31
# No readings found from 2024-07-01 to 2024-12-31
#
# time elapsed: 139.7661 | TOTAL_API_CALLS = 65
#
#
# sensor_id: 7973216 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7973216 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973216 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973216 | Fetched 398 readings from page 3 | Total readings - 2398
# Reached the end of data.
# Finished Fetching all data. Total readings are 2398 for sensor 7973216
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973216\2024\06\relativehumidity_7973216.csv
#
# sensor_id: 7973216 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7973216 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973216 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973216 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7973216 | Fetched 218 readings from page 4 | Total readings - 3218
# Reached the end of data.
# Finished Fetching all data. Total readings are 3218 for sensor 7973216
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973216\2024\12\relativehumidity_7973216.csv
#
# time elapsed: 154.3489 | TOTAL_API_CALLS = 72
#
#
# sensor_id: 7973216 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7973216 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973216 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973216 | Fetched 507 readings from page 3 | Total readings - 2507
# Reached the end of data.
# Finished Fetching all data. Total readings are 2507 for sensor 7973216
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973216\2025\06\relativehumidity_7973216.csv
#
# sensor_id: 7973216 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 7973216 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973216 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 7973216
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7973216\2025\12\relativehumidity_7973216.csv
#
# time elapsed: 165.5320 | TOTAL_API_CALLS = 77
#
#
# sensor_id: 7979183 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7979183 | Fetched 44 readings from page 1 | Total readings - 44
# Reached the end of data.
# Finished Fetching all data. Total readings are 44 for sensor 7979183
# saved the data to AQ_data\Chicago\West Albany Park, Chicago\7979183\2024\06\temperature_7979183.csv
#
# sensor_id: 7979183 | Fetching data from 2024-07-01 to 2024-12-31
# No readings found from 2024-07-01 to 2024-12-31
#
# time elapsed: 171.0876 | TOTAL_API_CALLS = 79
#
#
# sensor_id: 7970927 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7970927 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7970927 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7970927 | Fetched 348 readings from page 3 | Total readings - 2348
# Reached the end of data.
# Finished Fetching all data. Total readings are 2348 for sensor 7970927
# saved the data to AQ_data\Chicago\Winona\7970927\2024\06\pm1_7970927.csv
#
# sensor_id: 7970927 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7970927 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7970927 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7970927 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7970927 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 7970927 | Fetched 306 readings from page 5 | Total readings - 4306
# Reached the end of data.
# Finished Fetching all data. Total readings are 4306 for sensor 7970927
# saved the data to AQ_data\Chicago\Winona\7970927\2024\12\pm1_7970927.csv
#
# time elapsed: 15.9562 | TOTAL_API_CALLS = 87
#
#
# sensor_id: 7970927 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7970927 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7970927 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7970927 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7970927 | Fetched 507 readings from page 4 | Total readings - 3507
# Reached the end of data.
# Finished Fetching all data. Total readings are 3507 for sensor 7970927
# saved the data to AQ_data\Chicago\Winona\7970927\2025\06\pm1_7970927.csv
#
# sensor_id: 7970927 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 7970927 | Fetched 101 readings from page 1 | Total readings - 101
# Reached the end of data.
# Finished Fetching all data. Total readings are 101 for sensor 7970927
# saved the data to AQ_data\Chicago\Winona\7970927\2025\12\pm1_7970927.csv
#
# time elapsed: 28.6466 | TOTAL_API_CALLS = 92
#
#
# sensor_id: 7971067 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7971067 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971067 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7971067 | Fetched 348 readings from page 3 | Total readings - 2348
# Reached the end of data.
# Finished Fetching all data. Total readings are 2348 for sensor 7971067
# saved the data to AQ_data\Chicago\Winona\7971067\2024\06\pm10_7971067.csv
#
# sensor_id: 7971067 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7971067 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7971067 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7971067 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7971067 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 7971067 | Fetched 306 readings from page 5 | Total readings - 4306
# Reached the end of data.
# Finished Fetching all data. Total readings are 4306 for sensor 7971067
# saved the data to AQ_data\Chicago\Winona\7971067\2024\12\pm10_7971067.csv
#
# time elapsed: 47.6394 | TOTAL_API_CALLS = 100
#
#
# sensor_id: 7971067 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7971067 | Fetched 242 readings from page 1 | Total readings - 242
# Reached the end of data.
# Finished Fetching all data. Total readings are 242 for sensor 7971067
# saved the data to AQ_data\Chicago\Winona\7971067\2025\06\pm10_7971067.csv
#
# sensor_id: 7971067 | Fetching data from 2025-07-01 to 2025-12-31
# No readings found from 2025-07-01 to 2025-12-31
#
# time elapsed: 53.4969 | TOTAL_API_CALLS = 102
#
#
# sensor_id: 6764272 | Fetching data from 2023-01-01 to 2023-06-30
# No readings found from 2023-01-01 to 2023-06-30
#
# sensor_id: 6764272 | Fetching data from 2023-07-01 to 2023-12-31
# sensor_id: 6764272 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764272 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764272 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764272 | Fetched 24 readings from page 4 | Total readings - 3024
# Reached the end of data.
# Finished Fetching all data. Total readings are 3024 for sensor 6764272
# saved the data to AQ_data\Chicago\Winona\6764272\2023\12\temperature_6764272.csv
#
# time elapsed: 64.3442 | TOTAL_API_CALLS = 107
#
#
# sensor_id: 6764272 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 6764272 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764272 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764272 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764272 | Fetched 686 readings from page 4 | Total readings - 3686
# Reached the end of data.
# Finished Fetching all data. Total readings are 3686 for sensor 6764272
# saved the data to AQ_data\Chicago\Winona\6764272\2024\06\temperature_6764272.csv
#
# sensor_id: 6764272 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 6764272 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764272 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764272 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764272 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 6764272 | Fetched 306 readings from page 5 | Total readings - 4306
# Reached the end of data.
# Finished Fetching all data. Total readings are 4306 for sensor 6764272
# saved the data to AQ_data\Chicago\Winona\6764272\2024\12\temperature_6764272.csv
#
# time elapsed: 86.6903 | TOTAL_API_CALLS = 116
#
#
# sensor_id: 6764272 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 6764272 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764272 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764272 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764272 | Fetched 507 readings from page 4 | Total readings - 3507
# Reached the end of data.
# Finished Fetching all data. Total readings are 3507 for sensor 6764272
# saved the data to AQ_data\Chicago\Winona\6764272\2025\06\temperature_6764272.csv
#
# sensor_id: 6764272 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 6764272 | Fetched 101 readings from page 1 | Total readings - 101
# Reached the end of data.
# Finished Fetching all data. Total readings are 101 for sensor 6764272
# saved the data to AQ_data\Chicago\Winona\6764272\2025\12\temperature_6764272.csv
#
# time elapsed: 98.3160 | TOTAL_API_CALLS = 121
#
#
# sensor_id: 7979876 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7979876 | Fetched 44 readings from page 1 | Total readings - 44
# Reached the end of data.
# Finished Fetching all data. Total readings are 44 for sensor 7979876
# saved the data to AQ_data\Chicago\Winona\7979876\2024\06\pm10_7979876.csv
#
# sensor_id: 7979876 | Fetching data from 2024-07-01 to 2024-12-31
# No readings found from 2024-07-01 to 2024-12-31
#
# time elapsed: 104.0020 | TOTAL_API_CALLS = 123
#
#
# sensor_id: 7973023 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7973023 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973023 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973023 | Fetched 381 readings from page 3 | Total readings - 2381
# Reached the end of data.
# Finished Fetching all data. Total readings are 2381 for sensor 7973023
# saved the data to AQ_data\Chicago\Winona\7973023\2024\06\relativehumidity_7973023.csv
#
# sensor_id: 7973023 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7973023 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973023 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973023 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7973023 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 7973023 | Fetched 306 readings from page 5 | Total readings - 4306
# Reached the end of data.
# Finished Fetching all data. Total readings are 4306 for sensor 7973023
# saved the data to AQ_data\Chicago\Winona\7973023\2024\12\relativehumidity_7973023.csv
#
# time elapsed: 123.3284 | TOTAL_API_CALLS = 131
#
#
# sensor_id: 7973023 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7973023 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973023 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973023 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7973023 | Fetched 507 readings from page 4 | Total readings - 3507
# Reached the end of data.
# Finished Fetching all data. Total readings are 3507 for sensor 7973023
# saved the data to AQ_data\Chicago\Winona\7973023\2025\06\relativehumidity_7973023.csv
#
# sensor_id: 7973023 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 7973023 | Fetched 101 readings from page 1 | Total readings - 101
# Reached the end of data.
# Finished Fetching all data. Total readings are 101 for sensor 7973023
# saved the data to AQ_data\Chicago\Winona\7973023\2025\12\relativehumidity_7973023.csv
#
# time elapsed: 135.2094 | TOTAL_API_CALLS = 136
#
#
# sensor_id: 7979889 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7979889 | Fetched 44 readings from page 1 | Total readings - 44
# Reached the end of data.
# Finished Fetching all data. Total readings are 44 for sensor 7979889
# saved the data to AQ_data\Chicago\Winona\7979889\2024\06\pm1_7979889.csv
#
# sensor_id: 7979889 | Fetching data from 2024-07-01 to 2024-12-31
# No readings found from 2024-07-01 to 2024-12-31
#
# time elapsed: 140.7929 | TOTAL_API_CALLS = 138
#
#
# sensor_id: 6764273 | Fetching data from 2023-01-01 to 2023-06-30
# No readings found from 2023-01-01 to 2023-06-30
#
# sensor_id: 6764273 | Fetching data from 2023-07-01 to 2023-12-31
# sensor_id: 6764273 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764273 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764273 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764273 | Fetched 24 readings from page 4 | Total readings - 3024
# Reached the end of data.
# Finished Fetching all data. Total readings are 3024 for sensor 6764273
# saved the data to AQ_data\Chicago\Winona\6764273\2023\12\pm25_6764273.csv
#
# time elapsed: 151.7642 | TOTAL_API_CALLS = 143
#
#
# sensor_id: 6764273 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 6764273 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764273 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764273 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764273 | Fetched 686 readings from page 4 | Total readings - 3686
# Reached the end of data.
# Finished Fetching all data. Total readings are 3686 for sensor 6764273
# saved the data to AQ_data\Chicago\Winona\6764273\2024\06\pm25_6764273.csv
#
# sensor_id: 6764273 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 6764273 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764273 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764273 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764273 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 6764273 | Fetched 306 readings from page 5 | Total readings - 4306
# Reached the end of data.
# Finished Fetching all data. Total readings are 4306 for sensor 6764273
# saved the data to AQ_data\Chicago\Winona\6764273\2024\12\pm25_6764273.csv
#
# time elapsed: 170.3069 | TOTAL_API_CALLS = 152
#
#
# sensor_id: 6764273 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 6764273 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 6764273 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 6764273 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 6764273 | Fetched 507 readings from page 4 | Total readings - 3507
# Reached the end of data.
# Finished Fetching all data. Total readings are 3507 for sensor 6764273
# saved the data to AQ_data\Chicago\Winona\6764273\2025\06\pm25_6764273.csv
#
# sensor_id: 6764273 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 6764273 | Fetched 101 readings from page 1 | Total readings - 101
# Reached the end of data.
# Finished Fetching all data. Total readings are 101 for sensor 6764273
# saved the data to AQ_data\Chicago\Winona\6764273\2025\12\pm25_6764273.csv
#
# time elapsed: 181.2945 | TOTAL_API_CALLS = 157
#
#
# sensor_id: 7973069 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7973069 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973069 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973069 | Fetched 381 readings from page 3 | Total readings - 2381
# Reached the end of data.
# Finished Fetching all data. Total readings are 2381 for sensor 7973069
# saved the data to AQ_data\Chicago\Winona\7973069\2024\06\um003_7973069.csv
#
# sensor_id: 7973069 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7973069 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973069 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973069 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7973069 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 7973069 | Fetched 306 readings from page 5 | Total readings - 4306
# Reached the end of data.
# Finished Fetching all data. Total readings are 4306 for sensor 7973069
# saved the data to AQ_data\Chicago\Winona\7973069\2024\12\um003_7973069.csv
#
# time elapsed: 198.3482 | TOTAL_API_CALLS = 165
#
#
# sensor_id: 7973069 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7973069 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7973069 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7973069 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7973069 | Fetched 507 readings from page 4 | Total readings - 3507
# Reached the end of data.
# Finished Fetching all data. Total readings are 3507 for sensor 7973069
# saved the data to AQ_data\Chicago\Winona\7973069\2025\06\um003_7973069.csv
#
# sensor_id: 7973069 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 7973069 | Fetched 101 readings from page 1 | Total readings - 101
# Reached the end of data.
# Finished Fetching all data. Total readings are 101 for sensor 7973069
# saved the data to AQ_data\Chicago\Winona\7973069\2025\12\um003_7973069.csv
#
# time elapsed: 209.4180 | TOTAL_API_CALLS = 170
#
#
# sensor_id: 7635192 | Fetching data from 2024-01-01 to 2024-06-30
# sensor_id: 7635192 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7635192 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7635192 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7635192 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 7635192 | Fetched 200 readings from page 5 | Total readings - 4200
# Reached the end of data.
# Finished Fetching all data. Total readings are 4200 for sensor 7635192
# saved the data to AQ_data\Chicago\McCook\7635192\2024\06\pm25_7635192.csv
#
# sensor_id: 7635192 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 7635192 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7635192 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7635192 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7635192 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 7635192 | Fetched 376 readings from page 5 | Total readings - 4376
# Reached the end of data.
# Finished Fetching all data. Total readings are 4376 for sensor 7635192
# saved the data to AQ_data\Chicago\McCook\7635192\2024\12\pm25_7635192.csv
#
# time elapsed: 16.8150 | TOTAL_API_CALLS = 180
#
#
# sensor_id: 7635192 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 7635192 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7635192 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 7635192 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 7635192 | Fetched 1000 readings from page 4 | Total readings - 4000
# sensor_id: 7635192 | Fetched 278 readings from page 5 | Total readings - 4278
# Reached the end of data.
# Finished Fetching all data. Total readings are 4278 for sensor 7635192
# saved the data to AQ_data\Chicago\McCook\7635192\2025\06\pm25_7635192.csv
#
# sensor_id: 7635192 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 7635192 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 7635192 | Fetched 739 readings from page 2 | Total readings - 1739
# Reached the end of data.
# Finished Fetching all data. Total readings are 1739 for sensor 7635192
# saved the data to AQ_data\Chicago\McCook\7635192\2025\12\pm25_7635192.csv
#
# time elapsed: 31.9627 | TOTAL_API_CALLS = 187
#
#
# sensor_id: 10342172 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10342172 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10342172 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342172 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342172 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342172 | Fetched 98 readings from page 4 | Total readings - 3098
# Reached the end of data.
# Finished Fetching all data. Total readings are 3098 for sensor 10342172
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342172\2024\12\um003_10342172.csv
#
# time elapsed: 6.4837 | TOTAL_API_CALLS = 192
#
#
# sensor_id: 10342172 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10342172 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342172 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342172 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342172 | Fetched 529 readings from page 4 | Total readings - 3529
# Reached the end of data.
# Finished Fetching all data. Total readings are 3529 for sensor 10342172
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342172\2025\06\um003_10342172.csv
#
# sensor_id: 10342172 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 10342172 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342172 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 10342172
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342172\2025\12\um003_10342172.csv
#
# time elapsed: 21.0839 | TOTAL_API_CALLS = 198
#
#
# sensor_id: 10342174 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10342174 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10342174 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342174 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342174 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342174 | Fetched 98 readings from page 4 | Total readings - 3098
# Reached the end of data.
# Finished Fetching all data. Total readings are 3098 for sensor 10342174
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342174\2024\12\temperature_10342174.csv
#
# time elapsed: 31.4997 | TOTAL_API_CALLS = 203
#
#
# sensor_id: 10342174 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10342174 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342174 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342174 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342174 | Fetched 529 readings from page 4 | Total readings - 3529
# Reached the end of data.
# Finished Fetching all data. Total readings are 3529 for sensor 10342174
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342174\2025\06\temperature_10342174.csv
#
# sensor_id: 10342174 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 10342174 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342174 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 10342174
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342174\2025\12\temperature_10342174.csv
#
# time elapsed: 44.8209 | TOTAL_API_CALLS = 209
#
#
# sensor_id: 10342175 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10342175 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10342175 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342175 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342175 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342175 | Fetched 98 readings from page 4 | Total readings - 3098
# Reached the end of data.
# Finished Fetching all data. Total readings are 3098 for sensor 10342175
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342175\2024\12\pm25_10342175.csv
#
# time elapsed: 57.1112 | TOTAL_API_CALLS = 214
#
#
# sensor_id: 10342175 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10342175 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342175 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342175 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342175 | Fetched 529 readings from page 4 | Total readings - 3529
# Reached the end of data.
# Finished Fetching all data. Total readings are 3529 for sensor 10342175
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342175\2025\06\pm25_10342175.csv
#
# sensor_id: 10342175 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 10342175 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342175 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 10342175
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342175\2025\12\pm25_10342175.csv
#
# time elapsed: 70.6950 | TOTAL_API_CALLS = 220
#
#
# sensor_id: 10342177 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10342177 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10342177 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342177 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342177 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342177 | Fetched 98 readings from page 4 | Total readings - 3098
# Reached the end of data.
# Finished Fetching all data. Total readings are 3098 for sensor 10342177
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342177\2024\12\relativehumidity_10342177.csv
#
# time elapsed: 81.9253 | TOTAL_API_CALLS = 225
#
#
# sensor_id: 10342177 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10342177 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342177 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342177 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342177 | Fetched 529 readings from page 4 | Total readings - 3529
# Reached the end of data.
# Finished Fetching all data. Total readings are 3529 for sensor 10342177
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342177\2025\06\relativehumidity_10342177.csv
#
# sensor_id: 10342177 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 10342177 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342177 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 10342177
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342177\2025\12\relativehumidity_10342177.csv
#
# time elapsed: 95.6780 | TOTAL_API_CALLS = 231
#
#
# sensor_id: 10342178 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10342178 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10342178 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342178 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342178 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342178 | Fetched 98 readings from page 4 | Total readings - 3098
# Reached the end of data.
# Finished Fetching all data. Total readings are 3098 for sensor 10342178
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342178\2024\12\pm1_10342178.csv
#
# time elapsed: 106.5517 | TOTAL_API_CALLS = 236
#
#
# sensor_id: 10342178 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10342178 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342178 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342178 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342178 | Fetched 529 readings from page 4 | Total readings - 3529
# Reached the end of data.
# Finished Fetching all data. Total readings are 3529 for sensor 10342178
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342178\2025\06\pm1_10342178.csv
#
# sensor_id: 10342178 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 10342178 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342178 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 10342178
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342178\2025\12\pm1_10342178.csv
#
# time elapsed: 120.0827 | TOTAL_API_CALLS = 242
#
#
# sensor_id: 10342181 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10342181 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10342181 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10342181 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10342181 | Fetched 1000 readings from page 3 | Total readings - 3000
# sensor_id: 10342181 | Fetched 98 readings from page 4 | Total readings - 3098
# Reached the end of data.
# Finished Fetching all data. Total readings are 3098 for sensor 10342181
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342181\2024\12\pm10_10342181.csv
#
# time elapsed: 130.6824 | TOTAL_API_CALLS = 247
#
#
# sensor_id: 10342181 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10342181 | Fetched 242 readings from page 1 | Total readings - 242
# Reached the end of data.
# Finished Fetching all data. Total readings are 242 for sensor 10342181
# saved the data to AQ_data\Chicago\Portage Park - Chicago\10342181\2025\06\pm10_10342181.csv
#
# sensor_id: 10342181 | Fetching data from 2025-07-01 to 2025-12-31
# No readings found from 2025-07-01 to 2025-12-31
#
# time elapsed: 136.4369 | TOTAL_API_CALLS = 249
#
#
# sensor_id: 10659976 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10659976 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10659976 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10659976 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10659976 | Fetched 461 readings from page 3 | Total readings - 2461
# Reached the end of data.
# Finished Fetching all data. Total readings are 2461 for sensor 10659976
# saved the data to AQ_data\Chicago\Fairfield Avenue\10659976\2024\12\um003_10659976.csv
#
# time elapsed: 4.9512 | TOTAL_API_CALLS = 253
#
#
# sensor_id: 10659976 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10659976 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10659976 | Fetched 448 readings from page 2 | Total readings - 1448
# Reached the end of data.
# Finished Fetching all data. Total readings are 1448 for sensor 10659976
# saved the data to AQ_data\Chicago\Fairfield Avenue\10659976\2025\06\um003_10659976.csv
#
# sensor_id: 10659976 | Fetching data from 2025-07-01 to 2025-12-31
# No readings found from 2025-07-01 to 2025-12-31
#
# time elapsed: 12.6733 | TOTAL_API_CALLS = 256
#
#
# sensor_id: 10659980 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10659980 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10659980 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10659980 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10659980 | Fetched 461 readings from page 3 | Total readings - 2461
# Reached the end of data.
# Finished Fetching all data. Total readings are 2461 for sensor 10659980
# saved the data to AQ_data\Chicago\Fairfield Avenue\10659980\2024\12\pm25_10659980.csv
#
# time elapsed: 21.9283 | TOTAL_API_CALLS = 260
#
#
# sensor_id: 10659980 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10659980 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10659980 | Fetched 448 readings from page 2 | Total readings - 1448
# Reached the end of data.
# Finished Fetching all data. Total readings are 1448 for sensor 10659980
# saved the data to AQ_data\Chicago\Fairfield Avenue\10659980\2025\06\pm25_10659980.csv
#
# sensor_id: 10659980 | Fetching data from 2025-07-01 to 2025-12-31
# No readings found from 2025-07-01 to 2025-12-31
#
# time elapsed: 29.0996 | TOTAL_API_CALLS = 263
#
#
# sensor_id: 10660009 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10660009 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10660009 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10660009 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10660009 | Fetched 461 readings from page 3 | Total readings - 2461
# Reached the end of data.
# Finished Fetching all data. Total readings are 2461 for sensor 10660009
# saved the data to AQ_data\Chicago\Fairfield Avenue\10660009\2024\12\pm1_10660009.csv
#
# time elapsed: 38.3474 | TOTAL_API_CALLS = 267
#
#
# sensor_id: 10660009 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10660009 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10660009 | Fetched 448 readings from page 2 | Total readings - 1448
# Reached the end of data.
# Finished Fetching all data. Total readings are 1448 for sensor 10660009
# saved the data to AQ_data\Chicago\Fairfield Avenue\10660009\2025\06\pm1_10660009.csv
#
# sensor_id: 10660009 | Fetching data from 2025-07-01 to 2025-12-31
# No readings found from 2025-07-01 to 2025-12-31
#
# time elapsed: 45.5653 | TOTAL_API_CALLS = 270
#
#
# sensor_id: 10660013 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10660013 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10660013 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10660013 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10660013 | Fetched 461 readings from page 3 | Total readings - 2461
# Reached the end of data.
# Finished Fetching all data. Total readings are 2461 for sensor 10660013
# saved the data to AQ_data\Chicago\Fairfield Avenue\10660013\2024\12\pm10_10660013.csv
#
# time elapsed: 55.0124 | TOTAL_API_CALLS = 274
#
#
# sensor_id: 10660013 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10660013 | Fetched 242 readings from page 1 | Total readings - 242
# Reached the end of data.
# Finished Fetching all data. Total readings are 242 for sensor 10660013
# saved the data to AQ_data\Chicago\Fairfield Avenue\10660013\2025\06\pm10_10660013.csv
#
# sensor_id: 10660013 | Fetching data from 2025-07-01 to 2025-12-31
# No readings found from 2025-07-01 to 2025-12-31
#
# time elapsed: 60.7573 | TOTAL_API_CALLS = 276
#
#
# sensor_id: 10660024 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10660024 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10660024 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10660024 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10660024 | Fetched 461 readings from page 3 | Total readings - 2461
# Reached the end of data.
# Finished Fetching all data. Total readings are 2461 for sensor 10660024
# saved the data to AQ_data\Chicago\Fairfield Avenue\10660024\2024\12\relativehumidity_10660024.csv
#
# time elapsed: 69.8881 | TOTAL_API_CALLS = 280
#
#
# sensor_id: 10660024 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 10660024 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10660024 | Fetched 448 readings from page 2 | Total readings - 1448
# Reached the end of data.
# Finished Fetching all data. Total readings are 1448 for sensor 10660024
# saved the data to AQ_data\Chicago\Fairfield Avenue\10660024\2025\06\relativehumidity_10660024.csv
#
# sensor_id: 10660024 | Fetching data from 2025-07-01 to 2025-12-31
# No readings found from 2025-07-01 to 2025-12-31
#
# time elapsed: 77.4206 | TOTAL_API_CALLS = 283
#
#
# sensor_id: 10660030 | Fetching data from 2024-01-01 to 2024-06-30
# No readings found from 2024-01-01 to 2024-06-30
#
# sensor_id: 10660030 | Fetching data from 2024-07-01 to 2024-12-31
# sensor_id: 10660030 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 10660030 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 10660030 | Fetched 461 readings from page 3 | Total readings - 2461
# Reached the end of data.
# Finished Fetching all data. Total readings are 2461 for sensor 10660030
# saved the data to AQ_data\Chicago\Fairfield Avenue\10660030\2024\12\temperature_10660030.csv
#
# time elapsed: 87.0087 | TOTAL_API_CALLS = 287
#
#
# sensor_id: 10660030 | Fetching data from 2025-01-01 to 2025-06-30
# ...
# Reached the end of data.
# Finished Fetching all data. Total readings are 443 for sensor 12360077
# saved the data to AQ_data\Chicago\Nettelhorst\12360077\2025\12\relativehumidity_12360077.csv
#
# time elapsed: 22.9463 | TOTAL_API_CALLS = 319
#
#
# sensor_id: 12360078 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 12360078 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 12360078 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 12360078 | Fetched 65 readings from page 3 | Total readings - 2065
# Reached the end of data.
# Finished Fetching all data. Total readings are 2065 for sensor 12360078
# saved the data to AQ_data\Chicago\Nettelhorst\12360078\2025\06\temperature_12360078.csv
#
# sensor_id: 12360078 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 12360078 | Fetched 443 readings from page 1 | Total readings - 443
# Reached the end of data.
# Finished Fetching all data. Total readings are 443 for sensor 12360078
# saved the data to AQ_data\Chicago\Nettelhorst\12360078\2025\12\temperature_12360078.csv
#
# time elapsed: 32.6026 | TOTAL_API_CALLS = 323
#
#
# sensor_id: 12360079 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 12360079 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 12360079 | Fetched 1000 readings from page 2 | Total readings - 2000
# sensor_id: 12360079 | Fetched 65 readings from page 3 | Total readings - 2065
# Reached the end of data.
# Finished Fetching all data. Total readings are 2065 for sensor 12360079
# saved the data to AQ_data\Chicago\Nettelhorst\12360079\2025\06\um003_12360079.csv
#
# sensor_id: 12360079 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 12360079 | Fetched 443 readings from page 1 | Total readings - 443
# Reached the end of data.
# Finished Fetching all data. Total readings are 443 for sensor 12360079
# saved the data to AQ_data\Chicago\Nettelhorst\12360079\2025\12\um003_12360079.csv
#
# time elapsed: 41.8200 | TOTAL_API_CALLS = 327
#
#
# sensor_id: 12856503 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 12856503 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 12856503 | Fetched 665 readings from page 2 | Total readings - 1665
# Reached the end of data.
# Finished Fetching all data. Total readings are 1665 for sensor 12856503
# saved the data to AQ_data\Chicago\Summit\12856503\2025\06\pm25_12856503.csv
#
# sensor_id: 12856503 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 12856503 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 12856503 | Fetched 709 readings from page 2 | Total readings - 1709
# Reached the end of data.
# Finished Fetching all data. Total readings are 1709 for sensor 12856503
# saved the data to AQ_data\Chicago\Summit\12856503\2025\12\pm25_12856503.csv
#
# time elapsed: 4.9410 | TOTAL_API_CALLS = 331
#
#
# sensor_id: 13230356 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13230356 | Fetched 632 readings from page 1 | Total readings - 632
# Reached the end of data.
# Finished Fetching all data. Total readings are 632 for sensor 13230356
# saved the data to AQ_data\Chicago\Avalon Park\13230356\2025\06\pm1_13230356.csv
#
# sensor_id: 13230356 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13230356 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13230356 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 13230356
# saved the data to AQ_data\Chicago\Avalon Park\13230356\2025\12\pm1_13230356.csv
#
# time elapsed: 3.4537 | TOTAL_API_CALLS = 334
#
#
# sensor_id: 13230357 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13230357 | Fetched 632 readings from page 1 | Total readings - 632
# Reached the end of data.
# Finished Fetching all data. Total readings are 632 for sensor 13230357
# saved the data to AQ_data\Chicago\Avalon Park\13230357\2025\06\pm25_13230357.csv
#
# sensor_id: 13230357 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13230357 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13230357 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 13230357
# saved the data to AQ_data\Chicago\Avalon Park\13230357\2025\12\pm25_13230357.csv
#
# time elapsed: 14.0738 | TOTAL_API_CALLS = 337
#
#
# sensor_id: 13230358 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13230358 | Fetched 632 readings from page 1 | Total readings - 632
# Reached the end of data.
# Finished Fetching all data. Total readings are 632 for sensor 13230358
# saved the data to AQ_data\Chicago\Avalon Park\13230358\2025\06\relativehumidity_13230358.csv
#
# sensor_id: 13230358 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13230358 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13230358 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 13230358
# saved the data to AQ_data\Chicago\Avalon Park\13230358\2025\12\relativehumidity_13230358.csv
#
# time elapsed: 22.2090 | TOTAL_API_CALLS = 340
#
#
# sensor_id: 13230359 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13230359 | Fetched 632 readings from page 1 | Total readings - 632
# Reached the end of data.
# Finished Fetching all data. Total readings are 632 for sensor 13230359
# saved the data to AQ_data\Chicago\Avalon Park\13230359\2025\06\temperature_13230359.csv
#
# sensor_id: 13230359 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13230359 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13230359 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 13230359
# saved the data to AQ_data\Chicago\Avalon Park\13230359\2025\12\temperature_13230359.csv
#
# time elapsed: 30.6939 | TOTAL_API_CALLS = 343
#
#
# sensor_id: 13230360 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13230360 | Fetched 632 readings from page 1 | Total readings - 632
# Reached the end of data.
# Finished Fetching all data. Total readings are 632 for sensor 13230360
# saved the data to AQ_data\Chicago\Avalon Park\13230360\2025\06\um003_13230360.csv
#
# sensor_id: 13230360 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13230360 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13230360 | Fetched 740 readings from page 2 | Total readings - 1740
# Reached the end of data.
# Finished Fetching all data. Total readings are 1740 for sensor 13230360
# saved the data to AQ_data\Chicago\Avalon Park\13230360\2025\12\um003_13230360.csv
#
# time elapsed: 38.8229 | TOTAL_API_CALLS = 346
#
#
# sensor_id: 13760568 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13760568 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13760568 | Fetched 967 readings from page 1 | Total readings - 967
# Reached the end of data.
# Finished Fetching all data. Total readings are 967 for sensor 13760568
# saved the data to AQ_data\Chicago\South Loop\13760568\2025\12\pm1_13760568.csv
#
# time elapsed: 1.6360 | TOTAL_API_CALLS = 348
#
#
# sensor_id: 13760569 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13760569 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13760569 | Fetched 967 readings from page 1 | Total readings - 967
# Reached the end of data.
# Finished Fetching all data. Total readings are 967 for sensor 13760569
# saved the data to AQ_data\Chicago\South Loop\13760569\2025\12\pm25_13760569.csv
#
# time elapsed: 7.8850 | TOTAL_API_CALLS = 350
#
#
# sensor_id: 13760570 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13760570 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13760570 | Fetched 967 readings from page 1 | Total readings - 967
# Reached the end of data.
# Finished Fetching all data. Total readings are 967 for sensor 13760570
# saved the data to AQ_data\Chicago\South Loop\13760570\2025\12\relativehumidity_13760570.csv
#
# time elapsed: 14.5655 | TOTAL_API_CALLS = 352
#
#
# sensor_id: 13760571 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13760571 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13760571 | Fetched 967 readings from page 1 | Total readings - 967
# Reached the end of data.
# Finished Fetching all data. Total readings are 967 for sensor 13760571
# saved the data to AQ_data\Chicago\South Loop\13760571\2025\12\temperature_13760571.csv
#
# time elapsed: 20.7859 | TOTAL_API_CALLS = 354
#
#
# sensor_id: 13760572 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13760572 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13760572 | Fetched 967 readings from page 1 | Total readings - 967
# Reached the end of data.
# Finished Fetching all data. Total readings are 967 for sensor 13760572
# saved the data to AQ_data\Chicago\South Loop\13760572\2025\12\um003_13760572.csv
#
# time elapsed: 27.0402 | TOTAL_API_CALLS = 356
#
#
# sensor_id: 13457439 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13457439 | Fetched 33 readings from page 1 | Total readings - 33
# Reached the end of data.
# Finished Fetching all data. Total readings are 33 for sensor 13457439
# saved the data to AQ_data\Chicago\Jeff Park\13457439\2025\06\pm1_13457439.csv
#
# sensor_id: 13457439 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13457439 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13457439 | Fetched 363 readings from page 2 | Total readings - 1363
# Reached the end of data.
# Finished Fetching all data. Total readings are 1363 for sensor 13457439
# saved the data to AQ_data\Chicago\Jeff Park\13457439\2025\12\pm1_13457439.csv
#
# time elapsed: 2.8059 | TOTAL_API_CALLS = 359
#
#
# sensor_id: 13457440 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13457440 | Fetched 33 readings from page 1 | Total readings - 33
# Reached the end of data.
# Finished Fetching all data. Total readings are 33 for sensor 13457440
# saved the data to AQ_data\Chicago\Jeff Park\13457440\2025\06\pm25_13457440.csv
#
# sensor_id: 13457440 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13457440 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13457440 | Fetched 363 readings from page 2 | Total readings - 1363
# Reached the end of data.
# Finished Fetching all data. Total readings are 1363 for sensor 13457440
# saved the data to AQ_data\Chicago\Jeff Park\13457440\2025\12\pm25_13457440.csv
#
# time elapsed: 10.0364 | TOTAL_API_CALLS = 362
#
#
# sensor_id: 13457441 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13457441 | Fetched 33 readings from page 1 | Total readings - 33
# Reached the end of data.
# Finished Fetching all data. Total readings are 33 for sensor 13457441
# saved the data to AQ_data\Chicago\Jeff Park\13457441\2025\06\relativehumidity_13457441.csv
#
# sensor_id: 13457441 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13457441 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13457441 | Fetched 363 readings from page 2 | Total readings - 1363
# Reached the end of data.
# Finished Fetching all data. Total readings are 1363 for sensor 13457441
# saved the data to AQ_data\Chicago\Jeff Park\13457441\2025\12\relativehumidity_13457441.csv
#
# time elapsed: 17.2068 | TOTAL_API_CALLS = 365
#
#
# sensor_id: 13457442 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13457442 | Fetched 33 readings from page 1 | Total readings - 33
# Reached the end of data.
# Finished Fetching all data. Total readings are 33 for sensor 13457442
# saved the data to AQ_data\Chicago\Jeff Park\13457442\2025\06\temperature_13457442.csv
#
# sensor_id: 13457442 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13457442 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13457442 | Fetched 363 readings from page 2 | Total readings - 1363
# Reached the end of data.
# Finished Fetching all data. Total readings are 1363 for sensor 13457442
# saved the data to AQ_data\Chicago\Jeff Park\13457442\2025\12\temperature_13457442.csv
#
# time elapsed: 24.8117 | TOTAL_API_CALLS = 368
#
#
# sensor_id: 13457443 | Fetching data from 2025-01-01 to 2025-06-30
# sensor_id: 13457443 | Fetched 33 readings from page 1 | Total readings - 33
# Reached the end of data.
# Finished Fetching all data. Total readings are 33 for sensor 13457443
# saved the data to AQ_data\Chicago\Jeff Park\13457443\2025\06\um003_13457443.csv
#
# sensor_id: 13457443 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13457443 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13457443 | Fetched 363 readings from page 2 | Total readings - 1363
# Reached the end of data.
# Finished Fetching all data. Total readings are 1363 for sensor 13457443
# saved the data to AQ_data\Chicago\Jeff Park\13457443\2025\12\um003_13457443.csv
#
# time elapsed: 32.0590 | TOTAL_API_CALLS = 371
#
#
# sensor_id: 13477544 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13477544 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13477544 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13477544 | Fetched 664 readings from page 2 | Total readings - 1664
# Reached the end of data.
# Finished Fetching all data. Total readings are 1664 for sensor 13477544
# saved the data to AQ_data\Chicago\Wells & Ontario Bus Station\13477544\2025\12\pm1_13477544.csv
#
# time elapsed: 2.7431 | TOTAL_API_CALLS = 374
#
#
# sensor_id: 13477545 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13477545 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13477545 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13477545 | Fetched 664 readings from page 2 | Total readings - 1664
# Reached the end of data.
# Finished Fetching all data. Total readings are 1664 for sensor 13477545
# saved the data to AQ_data\Chicago\Wells & Ontario Bus Station\13477545\2025\12\pm25_13477545.csv
#
# time elapsed: 10.6371 | TOTAL_API_CALLS = 377
#
#
# sensor_id: 13477546 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13477546 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13477546 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13477546 | Fetched 664 readings from page 2 | Total readings - 1664
# Reached the end of data.
# Finished Fetching all data. Total readings are 1664 for sensor 13477546
# saved the data to AQ_data\Chicago\Wells & Ontario Bus Station\13477546\2025\12\relativehumidity_13477546.csv
#
# time elapsed: 18.3796 | TOTAL_API_CALLS = 380
#
#
# sensor_id: 13477547 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13477547 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13477547 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13477547 | Fetched 664 readings from page 2 | Total readings - 1664
# Reached the end of data.
# Finished Fetching all data. Total readings are 1664 for sensor 13477547
# saved the data to AQ_data\Chicago\Wells & Ontario Bus Station\13477547\2025\12\temperature_13477547.csv
#
# time elapsed: 25.6144 | TOTAL_API_CALLS = 383
#
#
# sensor_id: 13477548 | Fetching data from 2025-01-01 to 2025-06-30
# No readings found from 2025-01-01 to 2025-06-30
#
# sensor_id: 13477548 | Fetching data from 2025-07-01 to 2025-12-31
# sensor_id: 13477548 | Fetched 1000 readings from page 1 | Total readings - 1000
# sensor_id: 13477548 | Fetched 664 readings from page 2 | Total readings - 1664
# Reached the end of data.
# Finished Fetching all data. Total readings are 1664 for sensor 13477548
# saved the data to AQ_data\Chicago\Wells & Ontario Bus Station\13477548\2025\12\um003_13477548.csv
#
# time elapsed: 33.4269 | TOTAL_API_CALLS = 386

# %%
loc
# Out:
# {'id': 1370216,
#  'name': 'West Albany Park, Chicago',
#  'locality': None,
#  'timezone': 'America/Chicago',
#  'country': {'id': 155, 'code': 'US', 'name': 'United States'},
#  'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#  'provider': {'id': 66, 'name': 'AirGradient'},
#  'isMobile': False,
#  'isMonitor': True,
#  'instruments': [{'id': 2, 'name': 'Government Monitor'},
#   {'id': 2, 'name': 'Government Monitor'}],
#  'sensors': [{'id': 7979159,
#    'name': 'pm1 µg/m³',
#    'parameter': {'id': 19,
#     'name': 'pm1',
#     'units': 'µg/m³',
#     'displayName': 'PM1'}},
#   {'id': 7971260,
#    'name': 'pm1 µg/m³',
#    'parameter': {'id': 19,
#     'name': 'pm1',
#     'units': 'µg/m³',
#     'displayName': 'PM1'}},
#   {'id': 7971006,
#    'name': 'pm10 µg/m³',
#    'parameter': {'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': 'PM10'}},
#   {'id': 7979145,
#    'name': 'pm10 µg/m³',
#    'parameter': {'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': 'PM10'}},
#   {'id': 7979186,
#    'name': 'pm25 µg/m³',
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': 'PM2.5'}},
#   {'id': 6664821,
#    'name': 'pm25 µg/m³',
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': 'PM2.5'}},
#   {'id': 7973216,
#    'name': 'relativehumidity %',
#    'parameter': {'id': 98,
#     'name': 'relativehumidity',
#     'units': '%',
#     'displayName': 'RH'}},
#   {'id': 7979183,
#    'name': 'temperature c',
#    'parameter': {'id': 100,
#     'name': 'temperature',
#     'units': 'c',
#     'displayName': 'Temperature (C)'}},
#   {'id': 6664822,
#    'name': 'temperature c',
#    'parameter': {'id': 100,
#     'name': 'temperature',
#     'units': 'c',
#     'displayName': 'Temperature (C)'}},
#   {'id': 7973201,
#    'name': 'um003 particles/cm³',
#    'parameter': {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': 'PM0.3 count'}}],
#  'coordinates': {'latitude': 41.962434, 'longitude': -87.737472},
#  'licenses': [{'id': 41,
#    'name': 'CC BY 4.0',
#    'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#    'dateFrom': '2023-07-15',
#    'dateTo': None}],
#  'bounds': [-87.737472, 41.962434, -87.737472, 41.962434],
#  'distance': 10892.91019799,
#  'datetimeFirst': {'utc': '2023-08-02T01:00:00Z',
#   'local': '2023-08-01T20:00:00-05:00'},
#  'datetimeLast': {'utc': '2025-09-11T22:00:00Z',
#   'local': '2025-09-11T17:00:00-05:00'}}

# %%
import pandas as pd

df1 = pd.read_csv("./AQ_data/Chicago/CHI_COM/737/2020/12/o3_737.csv")
df2 = pd.read_csv("./AQ_data/Bangalore/BTM Layout, Bengaluru - CPCB/14635/2018/06/pm25_14635.csv")

# %%
df1.columns == df2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
some_path = "US Diplomatic Post: New Delhi"

# %%
some_path.replace(":", "_").replace(" ", "_")
